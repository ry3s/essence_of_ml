# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %%
# %run -i ex2_01.py
# Out:
# 15

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5, 5)
y = x ** 2
plt.plot(x, y)
plt.show()

# %%
a = 2
b = 1.2
print(type(a), type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
import math
print(math.sqrt(2))
print(math.exp(3))
print(math.log(5))
print(math.cos(math.pi))
print(math.sin(math.pi))
# Out:
# 1.4142135623730951
# 20.085536923187668
# 1.6094379124341003
# -1.0
# 1.2246467991473532e-16

# %%
class Person:
    def __init__(self, first_name='', last_name=''):
        self.first_name = first_name
        self.last_name = last_name
        
    def get_name(self):
        return self.first_name + ' ' + self.last_name
    
    def __str__(self):
        return self.first_name + ' ' + self.last_name

# %%
person1 = Person("John", "Smith")
print(person1.get_name())
print(person1)
# Out:
# John Smith
# John Smith

# %%
import csv

s = 0
with open("sample.csv") as f:
    reader = csv.reader(f) # csv ファイルを読み込む
    next(reader)
    for row in reader:
        s += int(row[1])
        
print(s)
# Out:
# 18

# %%
data = [[1, 'a', 1.1],
        [2, 'b', 1.2],
        [3, 'c', 1.3]]

with open('output.csv', 'w') as f:
    wr = csv.writer(f)
    for row in data:
        wr.writerow(row)

# %%
# !cat output.csv
# Out:
# 1,a,1.1
# 2,b,1.2
# 3,c,1.3

# %%
import json

data = {"a": 1, "b": "x", "c": [1, 2, 3], "d": {"a": 1, "b": 2}}
s = json.dumps(data) # json to string
s
# Out:
# '{"a": 1, "b": "x", "c": [1, 2, 3], "d": {"a": 1, "b": 2}}'

# %%
data2 = json.loads(s) # string to json
data2
# Out:
# {'a': 1, 'b': 'x', 'c': [1, 2, 3], 'd': {'a': 1, 'b': 2}}

# %%
d = {"a": 1, "b": 2, "c": 3}

try:
    print(d["d"])
except KeyError:
    print("KeyError")
# Out:
# KeyError

# %%
import numpy as np

def qeq(a, b, c):
    d = np.sqrt(b ** 2 - 4 * a * c)
    return ((-b + d) / (2 * a), (-b - d) / (2 * a))

# %%
qeq(1, 5, 6)
# Out:
# (-2.0, -3.0)

# %%
qeq(1, 1.000000001, 0.000000001)
# Out:
# (-1.0000000272292198e-09, -1.0)

# %%
def qeq(a, b, c):
    alpha = (-b - np.sign(b) * np.sqrt(b ** 2 - 4 * a * c))/ (2 * a)
    beta = c / (a * alpha)
    return (alpha, beta)

# %%
qeq(1, 5, 6)
# Out:
# (-3.0, -2.0)

# %%
qeq(1, 1.000000001, 0.000000001)
# Out:
# (-1.0, -1e-09)

# %%
def softplus(x):
    return np.log(1 + np.exp(x))

# %%
softplus(-1)
# Out:
# 0.31326168751822286

# %%
softplus(0)
# Out:
# 0.6931471805599453

# %%
softplus(1000)
# Out:
# /Users/sshun/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# inf

# %%
def softplus2(x):
    return max(0, x) + np.log(1 + np.exp(-abs(x)))

# %%
softplus2(0)
# Out:
# 0.6931471805599453

# %%
softplus2(1000)
# Out:
# 1000.0

# %%
x = np.linspace(-5, 5,300)
y1 = x ** 2
y2 = (x - 2) ** 2

plt.plot(x, y1, color='r')
plt.plot(x, y2, color='k', linestyle='--')
plt.show()

# %%
np.random.seed(100)
l = []
for _ in range(1000):
    l.append(np.random.randint(1, 7, size=10).sum())
    
plt.hist(l, 20, color="gray")
plt.show()

# %%
def f(x, y):
    return x ** 2 + y ** 2 / 4

x = np.linspace(-5, 5, 300)
y = np.linspace(-5, 5, 300)

xmesh, ymesh = np.meshgrid(x, y)
z = f(xmesh.ravel(), ymesh.ravel()).reshape(xmesh.shape)

colors = ["0.1", "0.3", "0.5", "0.7"]
plt.contourf(x, y, z, color="k", levels=[1, 2, 3, 4, 5])
plt.show()
# Out:
# /Users/sshun/.pyenv/versions/3.7.4/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: The following kwargs were not used by contour: 'color'
#   # This is added back by InteractiveShellApp.init_path()

# %%
# %run -i gd_test1.py
# Out:
# [3.45722846e-07 1.00000048e+00]
# -2.9999999999997073
# gd_test1.py:34: UserWarning: The following kwargs were not used by contour: 'color'
#   levels=levels, color="k", linestyles="dotted")

# %%
# %run -i gd_test2.py
# Out:
# gd_test2.py:17: RuntimeWarning: overflow encountered in double_scalars
#   return np.array([10 * x - 6 * y + 6, -6 * x + 6 * y - 6])
# gd_test2.py:46: UserWarning: The following kwargs were not used by contour: 'color'
#   levels=levels, color="k", linestyles="dotted")

# %%
# %run -i newton_test1.py
# Out:
# [0.92071038 0.39024659]
# [-0.92071038 -0.39024659]
# [0.92071038 0.39024659]
# newton_test1.py:34: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(xmesh, ymesh, z1, color='r', levels=[0])
# newton_test1.py:35: UserWarning: The following kwargs were not used by contour: 'color'
#   plt.contour(xmesh, ymesh, z2, color='k', levels=[0])

# %%
# %run -i normdist.py

# %%
# %run -i cointoss.py

# %%
# %run -i reg1dim2.py

# %%
import linearreg

# %%
# %run -i reg_test1.py
# Out:
# coef:  [1.11450326 1.95737004 3.00295751]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/essence_of_ml/reg_test1.py in <module>
#      16 model.fit(X, y)
#      17 print("coef: ", model.w_)
# ---> 18 print("(1, 1): ", model.predict(np.array([1, 1])))
#      19
#      20 xmesh, ymesh = np.meshgrid(np.linspace(0, scale, 20),
#
# ~/essence_of_ml/linearreg.py in predict(self, X)
#      14
#      15     def predict(self, X):
# ---> 16         if X.ndim == 1:
#      17             X = X.reshape(1, -1)
#      18         Xtil = np.c_[np.ones(X.shape[0]), X]
#
# AttributeError: 'numpy.ndarray' object has no attribute 'dim'

# %%
# %run -i ridge_test1.py

# %%
# %run -i ridge_test2.py
